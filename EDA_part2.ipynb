# %% [markdown]
# # Workforce flow. EDA. Part 2.

# %% [markdown]
# | Feature                     | Decision | Reason |
# |-----------------------------|---------------------------|--------|
# | search_term                 | ❌ Exclude                   | Not relevant for career transitions. |
# | id                          | ✅ Include                   | Unique identifier for individuals. |
# | urn                         | ❌ Exclude                     | Internal LinkedIn identifier, not useful for analysis. |
# | profile_link                | ❌ Exclude                     | Used for accessing profiles, not needed for visualization. |
# | profile_id                  | ❌ Exclude                   | Redundant if `id` is included. |
# | name                        | ✅ Include                   | Useful for labeling nodes. |
# | first_name                  | ❌ Exclude                     | Redundant since `name` includes it. |
# | last_name                   | ❌ Exclude                     | Redundant since `name` includes it. |
# | location                    | ✅ Include                   | Can be used for geographic career trend analysis. |
# | headline                    | ❌ Exclude                     | Mostly personal branding, not structured enough for transitions. |
# | estimated_age               | ✅ Include                   | Helps analyze career trends by age group. |
# | followers                   | ❌ Exclude                     | Not relevant for career transitions. |
# | connections                 | ❌ Exclude                     | Not directly related to career movement. |
# | mutuals                     | ❌ Exclude                     | More relevant for networking analysis than career transitions. |
# | is_connection               | ❌ Exclude                     | Not relevant for the project's focus. |
# | premium                     | ❌ Exclude                     | Subscription status does not impact career transitions. |
# | creator                     | ❌ Exclude                     | Not relevant to job transitions. |
# | influencer                  | ❌ Exclude                     | Not directly related to career shifts. |
# | open_to_work                | ❌ Exclude                     | Represents intent rather than actual transitions. |
# | is_hiring                   | ❌ Exclude                     | Not useful for visualizing career paths. |
# | current_position            | ❌ Exclude                     | Key information for career transitions, but presents in `experience`. |
# | current_company             | ❌ Exclude                     | Essential for visualizing company-based career shifts, but presents in `experience`. |
# | past_company_1              | ❌ Exclude                     | Helps track career transitions, but presents in `experience`. |
# | past_company_2              | ❌ Exclude                     | Useful for analyzing multiple career moves, but presents in `experience`. |
# | school_1                    | ❌ Exclude                     | Important for educational background insights, but presents in `schools`. |
# | school_2                    | ❌ Exclude                     | Less relevant than primary school/university, and presents in `schools`. |
# | top_skill_1                 | ❌ Exclude                     | Presents in `skills`. |
# | top_skill_2                 | ❌ Exclude                     | Presents in `skills`. |
# | top_skill_3                 | ❌ Exclude                     | Presents in `skills`. |
# | bio                         | ❌ Exclude                     | Unstructured text, not useful for transitions. |
# | experiences                 | ✅ Include                   | Key to tracking career progression. |
# | schools                     | ✅ Include                   | Helps in educational background analysis. |
# | skills                      | ✅ Include                   | Valuable for skill-based career trends. |
# | certifications              | ✅ Include                   | Adds information about professional development. |
# | languages                   | ❌ Exclude                     | Not directly related to career transitions. |
# | emails_in_bio               | ❌ Exclude                     | Not relevant and contains privacy concerns. |
# | potential_emails            | ❌ Exclude                     | No data available and privacy-sensitive. |
# | profile_photo               | ❌ Exclude                     | Not necessary for visualizing transitions. |
# | banner_photo                | ❌ Exclude                     | Not useful for analysis. |
# | connection_created_at       | ❌ Exclude                     | Irrelevant for career transitions. |
# | connection_email            | ❌ Exclude                     | Privacy-sensitive and unnecessary. |
# | connection_phone_numbers    | ❌ Exclude                     | Privacy-sensitive, not useful. |
# | connection_websites         | ❌ Exclude                     | Not relevant for career transitions. |
# | connection_street_address   | ❌ Exclude                     | No data available, not relevant. |
# | connection_birthday         | ❌ Exclude                     | Not necessary for career transitions. |

# %% [markdown]
# ## Loading data

# %%
# !pip install googletrans==4.0.0-rc1
# Out:
# Collecting googletrans==4.0.0-rc1
#   Downloading googletrans-4.0.0rc1.tar.gz (20 kB)
#   Preparing metadata (setup.py) ... done
# Collecting httpx==0.13.3 (from googletrans==4.0.0-rc1)
#   Downloading httpx-0.13.3-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (2025.1.31)
# Collecting hstspreload (from httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading hstspreload-2025.1.1-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (1.3.1)
# Collecting chardet==3.* (from httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading chardet-3.0.4-py2.py3-none-any.whl.metadata (3.2 kB)
# Collecting idna==2.* (from httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading idna-2.10-py2.py3-none-any.whl.metadata (9.1 kB)
# Collecting rfc3986<2,>=1.3 (from httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading rfc3986-1.5.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting httpcore==0.9.* (from httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading httpcore-0.9.1-py3-none-any.whl.metadata (4.6 kB)
# Collecting h11<0.10,>=0.8 (from httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading h11-0.9.0-py2.py3-none-any.whl.metadata (8.1 kB)
# Collecting h2==3.* (from httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading h2-3.2.0-py2.py3-none-any.whl.metadata (32 kB)
# Collecting hyperframe<6,>=5.2.0 (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading hyperframe-5.2.0-py2.py3-none-any.whl.metadata (7.2 kB)
# Collecting hpack<4,>=3.0 (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading hpack-3.0.0-py2.py3-none-any.whl.metadata (7.0 kB)
# Downloading httpx-0.13.3-py3-none-any.whl (55 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.1/55.1 kB 4.0 MB/s eta 0:00:00
# Downloading chardet-3.0.4-py2.py3-none-any.whl (133 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.4/133.4 kB 6.1 MB/s eta 0:00:00
# Downloading httpcore-0.9.1-py3-none-any.whl (42 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 3.3 MB/s eta 0:00:00
# Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 5.0 MB/s eta 0:00:00
# Downloading h2-3.2.0-py2.py3-none-any.whl (65 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.0/65.0 kB 4.8 MB/s eta 0:00:00
# Downloading rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Downloading hstspreload-2025.1.1-py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 28.6 MB/s eta 0:00:00
# Downloading h11-0.9.0-py2.py3-none-any.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 4.5 MB/s eta 0:00:00
# Downloading hpack-3.0.0-py2.py3-none-any.whl (38 kB)
# Downloading hyperframe-5.2.0-py2.py3-none-any.whl (12 kB)
# Building wheels for collected packages: googletrans
#   Building wheel for googletrans (setup.py) ... done
#   Created wheel for googletrans: filename=googletrans-4.0.0rc1-py3-none-any.whl size=17397 sha256=e27583b113885caf805234347940bf5d2a0bc926bab3ec2fd5c6132ca22b972d
#   Stored in directory: /root/.cache/pip/wheels/39/17/6f/66a045ea3d168826074691b4b787b8f324d3f646d755443fda
# Successfully built googletrans
# Installing collected packages: rfc3986, hyperframe, hpack, h11, chardet, idna, hstspreload, h2, httpcore, httpx, googletrans
#   Attempting uninstall: hyperframe
#     Found existing installation: hyperframe 6.1.0
#     Uninstalling hyperframe-6.1.0:
#       Successfully uninstalled hyperframe-6.1.0
#   Attempting uninstall: hpack
#     Found existing installation: hpack 4.1.0
#     Uninstalling hpack-4.1.0:
#       Successfully uninstalled hpack-4.1.0
#   Attempting uninstall: h11
#     Found existing installation: h11 0.14.0
#     Uninstalling h11-0.14.0:
#       Successfully uninstalled h11-0.14.0
#   Attempting uninstall: chardet
#     Found existing installation: chardet 5.2.0
#     Uninstalling chardet-5.2.0:
#       Successfully uninstalled chardet-5.2.0
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
#   Attempting uninstall: h2
#     Found existing installation: h2 4.2.0
#     Uninstalling h2-4.2.0:
#       Successfully uninstalled h2-4.2.0
#   Attempting uninstall: httpcore
#     Found existing installation: httpcore 1.0.7
#     Uninstalling httpcore-1.0.7:
#       Successfully uninstalled httpcore-1.0.7
#   Attempting uninstall: httpx
#     Found existing installation: httpx 0.28.1
#     Uninstalling httpx-0.28.1:
#       Successfully uninstalled httpx-0.28.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# openai 1.68.2 requires httpx<1,>=0.23.0, but you have httpx 0.13.3 which is incompatible.
# langsmith 0.3.18 requires httpx<1,>=0.23.0, but you have httpx 0.13.3 which is incompatible.
# google-genai 1.7.0 requires httpx<1.0.0,>=0.28.1, but you have httpx 0.13.3 which is incompatible.
# Successfully installed chardet-3.0.4 googletrans-4.0.0rc1 h11-0.9.0 h2-3.2.0 hpack-3.0.0 hstspreload-2025.1.1 httpcore-0.9.1 httpx-0.13.3 hyperframe-5.2.0 idna-2.10 rfc3986-1.5.0

# %%
# Import required libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from googletrans import Translator
import re
import requests
from tqdm import tqdm

# %%
# Read dataset with 100 collected users for each file
root = 'users/'
users_0_100 = pd.read_csv(f'{root}users_0_100.csv')
users_100_200 = pd.read_csv(f'{root}users_100_200.csv')
users_200_300 = pd.read_csv(f'{root}users_200_300.csv')
users_300_400 = pd.read_csv(f'{root}users_300_400.csv')
users_400_500 = pd.read_csv(f'{root}users_400_500.csv')
users_500_550 = pd.read_csv(f'{root}users_500_550.csv')
users_550_552 = pd.read_csv(f'{root}users_550_552.csv')
users_552_600 = pd.read_csv(f'{root}users_552_600.csv')
users_600_700 = pd.read_csv(f'{root}users_600_700.csv')
users_700_745 = pd.read_csv(f'{root}users_700_745.csv')
users_745_843 = pd.read_csv(f'{root}users_745_843.csv')

# %%
# Concatenate all dataframes into one common users dataframe
users = pd.concat([users_0_100,
                   users_100_200,
                   users_200_300,
                   users_300_400,
                   users_400_500,
                   users_500_550,
                   users_550_552,
                   users_552_600,
                   users_600_700,
                   users_700_745,
                   users_745_843], ignore_index=True)
users.head()
# Out:
#   search_term                                       id        urn  \
# 0      manual  ACoAAA_dS7gB-ucqa7BZwzbO1-kVxInduE2bsOg  266161080
# 1      manual  ACoAAA_XHtcBA0rpWCcoM3yhkMOy04zzSKnd804  265756375
# 2      manual  ACoAAA-ECYcB5_w3-SWAt3dPl2KOOSo7kA9NyfI  260311431
# 3      manual  ACoAAA00XfsBNdzmLH9mWWzP5jgdk-nu0YdDFRo  221535739
# 4      manual  ACoAAA0ImOkB2Ninxe_GudoAdBSx1Lt0sKb4R5g  218667241
#
#                                         profile_link  \
# 0  https://www.linkedin.com/in/ACoAAA_dS7gB-ucqa7...
# 1  https://www.linkedin.com/in/ACoAAA_XHtcBA0rpWC...
# 2  https://www.linkedin.com/in/ACoAAA-ECYcB5_w3-S...
# 3  https://www.linkedin.com/in/ACoAAA00XfsBNdzmLH...
# 4  https://www.linkedin.com/in/ACoAAA0ImOkB2Ninxe...
#
#                                   profile_id  \
# 0  roberto-enrique-chavez-rodriguez-4a017875
# 1                             maxim-shalavin
# 2                              zaplatinaolga
# 3                                   fazullin
# 4                               vasiliizorin
#
#                                name       first_name         last_name  \
# 0  Roberto Enrique Chavez Rodriguez  Roberto Enrique  Chavez Rodriguez
# 1                    Maxim Shalavin            Maxim          Shalavin
# 2                           Olga Z.             Olga                Z.
# 3                    Timur Fazullin            Timur          Fazullin
# 4                     Vasilii Zorin          Vasilii             Zorin
#
#                                          location  \
# 0  Buenos Aires, Buenos Aires Province, Argentina
# 1                                Tbilisi, Georgia
# 2                        Kazan, Tatarstan, Russia
# 3                    Innopolis, Tatarstan, Russia
# 4                        Toronto, Ontario, Canada
#
#                                             headline  ...  emails_in_bio  \
# 0  Software Engineer at the Center of Oil and Gas...  ...            NaN
# 1  Team Lead | Senior Golang Developer | Blockcha...  ...            NaN
# 2  Project management | internal communications |...  ...            NaN
# 3                Head of Communications and Branding  ...            NaN
# 4                    Lead Product Manager at Acronis  ...            NaN
#
#    potential_emails                                      profile_photo  \
# 0               NaN  https://media.licdn.com/dms/image/v2/C4E03AQFZ...
# 1               NaN  https://media.licdn.com/dms/image/v2/D4D03AQEQ...
# 2               NaN  https://media.licdn.com/dms/image/v2/C4E03AQHl...
# 3               NaN  https://media.licdn.com/dms/image/v2/C4D03AQFF...
# 4               NaN  https://media.licdn.com/dms/image/v2/D4D03AQHz...
#
#                                         banner_photo connection_created_at  \
# 0  https://media.licdn.com/dms/image/v2/C4E16AQF5...                   NaN
# 1  https://media.licdn.com/dms/image/v2/D4D16AQEq...                   NaN
# 2  https://media.licdn.com/dms/image/v2/C4E16AQHR...                   NaN
# 3                                                NaN                   NaN
# 4                                                NaN                   NaN
#
#    connection_email  connection_phone_numbers  \
# 0               NaN                        []
# 1               NaN                        []
# 2               NaN                        []
# 3               NaN                        []
# 4               NaN                        []
#
#                connection_websites  connection_street_address  \
# 0                               []                        NaN
# 1  ['https://github.com/sansaian']                        NaN
# 2                               []                        NaN
# 3       ['https://fazullin.site/']                        NaN
# 4                               []                        NaN
#
#    connection_birthday
# 0               May 29
# 1                  NaN
# 2            August 30
# 3                  NaN
# 4               May 12
#
# [5 rows x 45 columns]

# %%
users = users[['id', 'name', 'location', 'estimated_age',
               'experiences', 'schools', 'skills', 'certifications']].copy()

# %%
# Check duplicated profile_id in dataset
users.duplicated(subset='id').sum()
# Out:
# np.int64(0)

# %%
# Check duplicated profile_id in dataset
users.duplicated().sum()
# Out:
# np.int64(0)

# %%
users.head()
# Out:
#                                         id                              name  \
# 0  ACoAAA_dS7gB-ucqa7BZwzbO1-kVxInduE2bsOg  Roberto Enrique Chavez Rodriguez
# 1  ACoAAA_XHtcBA0rpWCcoM3yhkMOy04zzSKnd804                    Maxim Shalavin
# 2  ACoAAA-ECYcB5_w3-SWAt3dPl2KOOSo7kA9NyfI                           Olga Z.
# 3  ACoAAA00XfsBNdzmLH9mWWzP5jgdk-nu0YdDFRo                    Timur Fazullin
# 4  ACoAAA0ImOkB2Ninxe_GudoAdBSx1Lt0sKb4R5g                     Vasilii Zorin
#
#                                          location  estimated_age  \
# 0  Buenos Aires, Buenos Aires Province, Argentina           35.0
# 1                                Tbilisi, Georgia           34.0
# 2                        Kazan, Tatarstan, Russia           37.0
# 3                    Innopolis, Tatarstan, Russia           40.0
# 4                        Toronto, Ontario, Canada           31.0
#
#                                          experiences  \
# 0  [{'start_date': '2022-01-14', 'end_date': '202...
# 1  [{'start_date': '2023-04-14', 'end_date': None...
# 2  [{'start_date': '2023-05-14', 'end_date': None...
# 3  [{'start_date': '2024-10-14', 'end_date': None...
# 4  [{'start_date': '2023-11-14', 'end_date': None...
#
#                                              schools  \
# 0  [{'start_date': '2021-08-14', 'end_date': '202...
# 1  [{'start_date': '2015-03-14', 'end_date': '201...
# 2  [{'start_date': '2011-03-14', 'end_date': '201...
# 3  [{'start_date': '2003-03-14', 'end_date': '200...
# 4  [{'start_date': '2019-03-14', 'end_date': '202...
#
#                                               skills  \
# 0  [{'name': 'JavaScript', 'endorsements': 0, 'pa...
# 1  [{'name': 'Java', 'endorsements': 0, 'passed_a...
# 2  [{'name': 'English', 'endorsements': 16, 'pass...
# 3  [{'name': 'Контент-маркетинг', 'endorsements':...
# 4  [{'name': 'Scrum', 'endorsements': 14, 'passed...
#
#                                       certifications
# 0  [{'title': 'Duolingo German Fluency: Elementar...
# 1  [{'title': 'Apache Kafka Essential Training: G...
# 2  [{'title': 'ESL: Improving Oral Skills (18)', ...
# 3                                                NaN
# 4  [{'title': 'Certified SAFe 4 Agilist', 'issuer...

# %%
users.shape
# Out:
# (840, 8)

# %%
# Calculate percentage of missing values in all columns
for column in users.columns:
    missing_percentage = (users[column].isnull().sum() / users.shape[0]) * 100
    print(f'Percentage of missing values in \'{column}\' column: {round(missing_percentage, 3)}%')
# Out:
# Percentage of missing values in 'id' column: 0.0%
# Percentage of missing values in 'name' column: 0.0%
# Percentage of missing values in 'location' column: 0.238%
# Percentage of missing values in 'estimated_age' column: 3.81%
# Percentage of missing values in 'experiences' column: 2.381%
# Percentage of missing values in 'schools' column: 1.071%
# Percentage of missing values in 'skills' column: 7.976%
# Percentage of missing values in 'certifications' column: 61.667%

# %%
# Fill missing values in location
users.fillna({'location': 'no location'}, inplace=True)

# %%
# Fill missing list values separately
for col in ['experiences', 'schools', 'skills', 'certifications']:
    users[col] = users[col].apply(lambda x: [] if pd.isna(x) else x)

# %% [markdown]
# ## Language Standardization

# %%
# Initialize the translator
translator = Translator()

# Apply progress bar to dataframe
tqdm.pandas()

# Function to translate text to English
def translate_to_english(text):

    # Detect non-English characters
    if text and not text.isascii():
        try:
            return translator.translate(text, dest='en').text
        except:
            return text
    return text

# %% [markdown]
# ## "Experiences" column

# %% [markdown]
# ### Extracting needed information

# %%
import ast

# Create list for users experiences
users_experiences = []

# Go through users['experiences'] to convert it in proper format
for experiences in users['experiences']:
    # If experience is empty, then skip it
    if len(experiences) == 0:
        users_experiences.append([])
        continue

    # Convert the string to a list
    data_list = ast.literal_eval(experiences)
    user_experiences = []

    # Store only dates, position, company name, and work type (full time, part time, and etc.)
    for experience in data_list:
        user_experience = {'start_date': experience['start_date'],
                            'end_date': experience['end_date'],
                            'title': experience['title'],
                            'company': experience['company'],
                            'emp_type': experience['emp_type']
                            }

        user_experiences.append(user_experience)
    users_experiences.append(user_experiences)

# %%
# Extract only unique positions for language standartization
titles = set()
for experiences in users_experiences:
    for experience in experiences:
        titles.add(experience['title'])

# %%
len(titles)
# Out:
# 2283

# %%
titles_list = list(titles)

# %%
# Translate to English all positions and store its translation
translated_titles = {}
for title in tqdm(titles_list):
    translated_titles[title] = translate_to_english(title)
# Out:
# 100%|██████████| 2283/2283 [02:31<00:00, 15.07it/s]

# %%
# Convert positions in dataframe to English version
for experiences in users_experiences:
    for experience in experiences:
        experience['title'] = translated_titles[experience['title']]

# %%
# Assign new experiences column
users['experiences'] = users_experiences

# %%
users['experiences'][0]
# Out:
# [{'start_date': '2022-01-14',
#   'end_date': '2023-07-14',
#   'title': 'Java Software Developer',
#   'company': 'Innopolis University',
#   'emp_type': 'full-time'},
#  {'start_date': '2016-06-14',
#   'end_date': '2016-10-14',
#   'title': 'Energy Engineer',
#   'company': 'Tech Mahindra',
#   'emp_type': None},
#  {'start_date': '2015-05-14',
#   'end_date': '2016-05-14',
#   'title': 'Mechanical Engineer',
#   'company': 'FINILAGER S.A.',
#   'emp_type': None},
#  {'start_date': '2012-02-14',
#   'end_date': '2014-12-14',
#   'title': 'Graduate Teaching Assistant',
#   'company': 'Universidad Mayor de San Andres',
#   'emp_type': None},
#  {'start_date': '2013-08-14',
#   'end_date': '2013-12-14',
#   'title': 'Mechanical Engineer',
#   'company': 'FCM Bolivia',
#   'emp_type': None},
#  {'start_date': '2013-08-14',
#   'end_date': '2013-09-14',
#   'title': 'Translator and Logistics coordinator',
#   'company': 'Suma Huasij – NGO to help Communities',
#   'emp_type': None},
#  {'start_date': '2013-01-14',
#   'end_date': '2013-07-14',
#   'title': 'Volunteer',
#   'company': 'Vamos Juntos Bolivia',
#   'emp_type': None},
#  {'start_date': '2012-01-14',
#   'end_date': '2012-02-14',
#   'title': 'Mechanic Technician',
#   'company': 'Inesco S.A',
#   'emp_type': None}]

# %%
users.head()
# Out:
#                                         id                              name  \
# 0  ACoAAA_dS7gB-ucqa7BZwzbO1-kVxInduE2bsOg  Roberto Enrique Chavez Rodriguez
# 1  ACoAAA_XHtcBA0rpWCcoM3yhkMOy04zzSKnd804                    Maxim Shalavin
# 2  ACoAAA-ECYcB5_w3-SWAt3dPl2KOOSo7kA9NyfI                           Olga Z.
# 3  ACoAAA00XfsBNdzmLH9mWWzP5jgdk-nu0YdDFRo                    Timur Fazullin
# 4  ACoAAA0ImOkB2Ninxe_GudoAdBSx1Lt0sKb4R5g                     Vasilii Zorin
#
#                                          location  estimated_age  \
# 0  Buenos Aires, Buenos Aires Province, Argentina           35.0
# 1                                Tbilisi, Georgia           34.0
# 2                        Kazan, Tatarstan, Russia           37.0
# 3                    Innopolis, Tatarstan, Russia           40.0
# 4                        Toronto, Ontario, Canada           31.0
#
#                                          experiences  \
# 0  [{'start_date': '2022-01-14', 'end_date': '202...
# 1  [{'start_date': '2023-04-14', 'end_date': None...
# 2  [{'start_date': '2023-05-14', 'end_date': None...
# 3  [{'start_date': '2024-10-14', 'end_date': None...
# 4  [{'start_date': '2023-11-14', 'end_date': None...
#
#                                              schools  \
# 0  [{'start_date': '2021-08-14', 'end_date': '202...
# 1  [{'start_date': '2015-03-14', 'end_date': '201...
# 2  [{'start_date': '2011-03-14', 'end_date': '201...
# 3  [{'start_date': '2003-03-14', 'end_date': '200...
# 4  [{'start_date': '2019-03-14', 'end_date': '202...
#
#                                               skills  \
# 0  [{'name': 'JavaScript', 'endorsements': 0, 'pa...
# 1  [{'name': 'Java', 'endorsements': 0, 'passed_a...
# 2  [{'name': 'English', 'endorsements': 16, 'pass...
# 3  [{'name': 'Контент-маркетинг', 'endorsements':...
# 4  [{'name': 'Scrum', 'endorsements': 14, 'passed...
#
#                                       certifications
# 0  [{'title': 'Duolingo German Fluency: Elementar...
# 1  [{'title': 'Apache Kafka Essential Training: G...
# 2  [{'title': 'ESL: Improving Oral Skills (18)', ...
# 3                                                 []
# 4  [{'title': 'Certified SAFe 4 Agilist', 'issuer...

# %%
# Convert to JSON and save
users.to_json("users.json", orient="records", indent=4)

# %% [markdown]
# ### Position clusterization

# %%
# !pip install umap-learn
# Out:
# Requirement already satisfied: umap-learn in /usr/local/lib/python3.11/dist-packages (0.5.7)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from umap-learn) (2.0.2)
# Requirement already satisfied: scipy>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from umap-learn) (1.14.1)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.11/dist-packages (from umap-learn) (1.6.1)
# Requirement already satisfied: numba>=0.51.2 in /usr/local/lib/python3.11/dist-packages (from umap-learn) (0.60.0)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.11/dist-packages (from umap-learn) (0.5.13)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from umap-learn) (4.67.1)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.51.2->umap-learn) (0.43.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.11/dist-packages (from pynndescent>=0.5->umap-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=0.22->umap-learn) (3.6.0)

# %%
import umap.umap_ as umap
import torch
from sentence_transformers import SentenceTransformer
from matplotlib.lines import Line2D

# %%
positions = list(translated_titles.values())

# %% [markdown]
# #### Work with word embeddings

# %%
# Check if CUDA is available and set the device
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f"Using device: {device}")

# Load a pre-trained SentenceTransformer model on CUDA
model = SentenceTransformer('all-MiniLM-L6-v2').to(device)

# Convert abstracts to embeddings
embeddings = model.encode(positions, convert_to_tensor=True, device=device)
embeddings = embeddings.cpu().numpy()  # Move back to CPU for UMAP
print("embeddings are ready!")
# Out:
# Using device: cpu
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# embeddings are ready!

# %%
# Reduce dimensionality using UMAP
reducer = umap.UMAP(n_neighbors=5, n_components=2, metric='cosine')
embedding_2d = reducer.fit_transform(embeddings)
print("Reducing dimensionality is complete!")
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Reducing dimensionality is complete!

# %%
# Plot the embeddings
plt.figure(figsize=(15, 15))

# Use a colormap that supports many categories (e.g., 'tab20', 'gist_ncar')
scatter = plt.scatter(embedding_2d[:, 0], embedding_2d[:, 1], s=5, alpha=0.8)

plt.title("Position Embeddings in 2D Space", fontsize=16)
plt.xlabel("UMAP Dimension 1")
plt.ylabel("UMAP Dimension 2")
plt.grid(True)
plt.show()

# %% [markdown]
# #### KMean

# %%
# Apply clustering (choose an appropriate number of clusters)
from sklearn.cluster import KMeans

num_clusters = 10
kmeans = KMeans(n_clusters=num_clusters, random_state=42)
labels = kmeans.fit_predict(embeddings)

# %%
plt.figure(figsize=(15, 15))
scatter = plt.scatter(embedding_2d[:, 0], embedding_2d[:, 1], s=5, c=labels, alpha=0.8)

plt.title("Position Embeddings in 2D Space", fontsize=16)
plt.xlabel("UMAP Dimension 1")
plt.ylabel("UMAP Dimension 2")
plt.grid(True)
plt.show()

# %% [markdown]
# #### Fuzzy matching

# %%
# !pip install fuzzywuzzy
# Out:
# Collecting fuzzywuzzy
#   Downloading fuzzywuzzy-0.18.0-py2.py3-none-any.whl.metadata (4.9 kB)
# Downloading fuzzywuzzy-0.18.0-py2.py3-none-any.whl (18 kB)
# Installing collected packages: fuzzywuzzy
# Successfully installed fuzzywuzzy-0.18.0

# %%
import spacy
from fuzzywuzzy import process

# Load spaCy NER model
nlp = spacy.load("en_core_web_sm")

# Define standard job title
STANDARD_JOB_TITLES = {"Software Development":0,
                       "Data Science & AI":1,
                       "Cybersecurity":2,
                       "Research & Academia":3,
                       "Operations & Management":4,
                       "Design & UX/UI":5,
                       "Marketing & Sales":6
                       }


def standardize_title(title):
    """Finds the closest match for a job title from the predefined standard titles."""
    match, score = process.extractOne(title, STANDARD_JOB_TITLES.keys())
    return STANDARD_JOB_TITLES[match]


labels = []
# Clusterize job titles
for position in tqdm(positions, total=len(positions)):
    labels.append(standardize_title(position))
# Out:
# 100%|██████████| 2283/2283 [00:07<00:00, 318.73it/s]

# %%
# Print job titles with assigned clusters
for job, label in zip(positions, labels):
    if label == 1:
        print(f"{job}: Cluster {label}")
# Out:
# Head of Laboratory, Cloud systems and service virtualization: Cluster 1
# PhD - Engineering and Applied Science: Cluster 1
# Chief Product Officer (Co-Founder): Cluster 1
# Big Data Engineer: Cluster 1
# Director, Center for autonomous technologies: Cluster 1
# Chief robotics scientist: Cluster 1
# Co-Founder, Data Scientist: Cluster 1
# Senior Student Affairs Specialist: Cluster 1
# Data Science Research Intern: Cluster 1
# Full Stack Engineer: Cluster 1
# Head of Data & Analytics: Cluster 1
# Student at MSc in Financial Engineering program (online): Cluster 1
# Junior Researcher in Service Science and Engineering Laboratory: Cluster 1
# Data analyst: Cluster 1
# engineer: Cluster 1
# Product Head (B2C Mobile Appendix): Cluster 1
# Computer vision and machine learning engineer: Cluster 1
# Machine Learning Researcher @ AI Lab: Cluster 1
# Navigation Trainee: Cluster 1
# Director of Product: Cluster 1
# Senior Instructor : Cluster 1
# The head of the sector: Cluster 1
# Data engineer: Cluster 1
# Junior Data Scientist: Cluster 1
# DWH Platform Tech Lead: Cluster 1
# Java Instructor: Cluster 1
# Privacy-Preserving AI Researcher: Cluster 1
# Digital Forensics and Incident Response  Lab Engineer: Cluster 1
# Programming and Computer Science Teacher (Superviser): Cluster 1
# Set of Set of Listeners of Master's Programs: Cluster 1
# Education Project Director: Cluster 1
# CTF specialist: Cluster 1
# Associated Service Delivery Manager: Cluster 1
# Chief Strategy Officer (CSO): Cluster 1
# Graduate Student Senator: Cluster 1
# Business Assistant: Cluster 1
# Co-founder & CTO: Cluster 1
# Senior QA Automation Engineer: Cluster 1
# ML Research Engineer (first ML/AI hire): Cluster 1
# Senior Data Architect: Cluster 1
# Machine Learning Intern: Cluster 1
# Machine Learning Engineer: Cluster 1
# Master's degree in Data Science: Cluster 1
# Senior System Administrator: Cluster 1
# Site Reliability Engineer STEP intern: Cluster 1
# Data Science Intern : Cluster 1
# System Engineer / Project Manager: Cluster 1
# Social Media Specialist: Cluster 1
# DevOps/ Site-Reliability Engineer: Cluster 1
# Business Intelligence Lead: Cluster 1
# MSc graduated: Cluster 1
# Computer Science Consultant: Cluster 1
# Data Analyst Team Lead: Cluster 1
# 2019 Google Summer of Code student w/RDKit: Cluster 1
# MSc Exchange Student (AI and Robotics): Cluster 1
# Maintenance Engineer: Cluster 1
# Hardware Adaptation Engineer: Cluster 1
# Trainee: Cluster 1
# Middle Java Programmer: Cluster 1
# Chief Financial Officer: Cluster 1
# Data & Analytics lead: Cluster 1
# Associate Faculty: Cluster 1
# Platform Engineer: Cluster 1
# Digital Director: Cluster 1
# Senior Researcher, Algorithm Developer, Data Analyst: Cluster 1
# Lead Data Engineer: Cluster 1
# Digital Footprint Intelligence Analyst: Cluster 1
# Intern Hardware Adaptation Engineer: Cluster 1
# Chief Scientist: Cluster 1
# Middle IT Recruiter: Cluster 1
# Senior Usability Specialist: Cluster 1
# Analyst-Steder: Cluster 1
# Clinical Hands-On Experience: Cluster 1
# Senior Data/Research Scientist: Cluster 1
# Full-Stack Engineer: Cluster 1
# Senior Data Analyst: Cluster 1
# Individual entrepreneur with registration at the place of residence: Cluster 1
# Intern researcher at Network Science and Information Technology Lab: Cluster 1
# IT recruiter : Cluster 1
# Scientific Committee member: Cluster 1
# Assistant Professor of Computer Science : Cluster 1
# CEO: Cluster 1
# Laboratory Technician: Cluster 1
# Chief Product Officer (CIO, CDTO): Cluster 1
# Data Science and Python teacher: Cluster 1
# Intern: Cluster 1
# Student at Data Science program (online): Cluster 1
# Graduate Student: Cluster 1
# Lead specialist: Cluster 1
# Lead Data Scientist: Cluster 1
# Data Scientist \ Machine Learning Engineer: Cluster 1
# QA Automation Engineer (java): Cluster 1
# R&D Machine Learning Engineer: Cluster 1
# CEO and Data Scientist: Cluster 1
# QA Performance Test Engineer: Cluster 1
# Algorithms and Data Structure Specialist: Cluster 1
# Bridge Program Teaching Assistant: Cluster 1
# Threat Intelligence Analyst: Cluster 1
# Data Analyst: Cluster 1
# Co-Founder / CPO: Cluster 1
# C# Engineer: Cluster 1
# Departmental Representative for Computer Science: Cluster 1
# Internship Trainee: Cluster 1
# Computer Science Instructor: Cluster 1
# Teaching Assistant, Faculty of Computer Science,: Cluster 1
# Fullstack Engineer for Appen Limited: Cluster 1
# lab assistant: Cluster 1
# Lead Service Manager: Cluster 1
# Associate Service Delivery Manager: Cluster 1
#  CEO: Cluster 1
# Junior Python Data Engineer: Cluster 1
# Principal Data Scientist at the SAP Global Center of Excellence: Cluster 1
# Applied Scientist: Cluster 1
# Business Data Analyst: Cluster 1
# System and Database Administrator: Cluster 1
# Robotics Engineer | Robotics Instructor: Cluster 1
# IT Product Owner: Cluster 1
# Data Science intern: Cluster 1
# QA Engineer: Cluster 1
# Quality Assurance Test Engineer: Cluster 1
# Hardware Adaptation Intern: Cluster 1
# Mentor Data Analyst in Practicum: Cluster 1
# Assistant Electrical Engineer: Cluster 1
# Tech Instructor: Cluster 1
# Senior Teacher Asistant: Cluster 1
# Business Intelligence Engineer: Cluster 1
# Associate Professor in Robotics and AI: Cluster 1
# Senior Business Partner: Cluster 1
# Science Research Specialist: Cluster 1
# Chief Education Technology Officer: Cluster 1
# Artificial Intelligence Intern: Cluster 1
# Director of the Institute of Information Technology and Data Science: Cluster 1
# Database Architect: Cluster 1
# Big Data Engineer: Cluster 1
# Docent of intelligent robotics chair: Cluster 1
# Community Engagement Coordinator: Cluster 1
# Quality Assurance Automation Engineer: Cluster 1
# Principal Technical Specialist: Cluster 1
# Chief Product & Technology Officer: Cluster 1
# HR Business Partner: Cluster 1
# Analitic engineer: Cluster 1
# Analyst at the Center for Analytics and Reporting of the Institute of Additional Education: Cluster 1
# Technical Specialist: Cluster 1
# Intern: Cluster 1
# President of National Society of Black Engineers (NSBE) UMassD Chapter: Cluster 1
# Data analyst: Cluster 1
# Data Scientist - the Transer: Cluster 1
# Senior Data Engineer: Cluster 1
# Contractor on science grant RFBR grant 16-37-60089: Cluster 1
# Front End Lead: Cluster 1
# Product Analyst | Lavka: Cluster 1
# Math and Computer Science Program Manager: Cluster 1
# Chief Data Officer: Cluster 1
# Data scientist: Cluster 1
# Scientific Consultant: Cluster 1
# Creative Director: Cluster 1
# System Analyst: Cluster 1
# Business-analytic: Cluster 1
# Head of Competency Center for Internal Automation: Cluster 1
# Data Scientist: Cluster 1
# Junior Datascientist: Cluster 1
# Associate consultant Computer science  || Business Division: Cluster 1
# Java Engineer: Cluster 1
# CTO (Chief Technology Officer): Cluster 1
# Technical Support Engineer (2nd Line): Cluster 1
# Vice-Provost for Education: Cluster 1
# Geospatial Systems Analyst: Cluster 1
# Social Organiser: Cluster 1
# Senior Android Dev: Cluster 1
# Head of Social Sciences Lab: Cluster 1
# Senior Data Scientist, CIB Segment: Cluster 1
# Data analyst\Fullstack analyst: Cluster 1
# it technician: Cluster 1
# Machine Learning engineer: Cluster 1
# IT Recruiter: Cluster 1
# Intern DS: Cluster 1
# Consumer Insights Data Scientist: Cluster 1
# Chief Product Officer, co-founder: Cluster 1
# Doctoral Associate: Cluster 1
# Laboratory assistant in the center of robotics: Cluster 1
# QA Specialist: Cluster 1
# CEO / Head of Digitalisation Projects : Cluster 1
# Technical Support Specialist: Cluster 1
# Intern: Cluster 1
# Deep Learning Scientist: Cluster 1
# Front-End Engineer: Cluster 1
# Artificial Intelligence Institute Deputy Director: Cluster 1
# Data Scienctist/Data Analyst: Cluster 1
# Artificial Intelligence Analyst: Cluster 1
# Senior Lecturer in Computer Science: Cluster 1
# PhD Candidate in Engineering: Cluster 1
# THIRD ASSISTANT ENGINEER: Cluster 1
# Head of Small Molecule Drug Discovery: Cluster 1
# Chief Analyst: Cluster 1
# Junior Data Analyst: Cluster 1
# Data Architect: Cluster 1
# National Youth Service Corps (NYSC): Cluster 1
# IT Specialist: Cluster 1
# AI Engineer: Cluster 1
# Co-Founder & Head of AI: Cluster 1
# Usability Engineer (Intern): Cluster 1
# Financial Analyst: Cluster 1
# Founder and CRO at B-Rain Labs LLC.: Cluster 1
# Business Data Scientist (Risk Management): Cluster 1
# R&D Engineer (C/C++): Cluster 1
# Navigation Trainee Officer: Cluster 1
# Co-founder & CPO: Cluster 1
# Engineer: Cluster 1
# Staff Scientist: Cluster 1
# Java Teacher Assistant : Cluster 1
# Part-time Teaching Assistant: Cluster 1
# AI Researcher & Builder & Founder: Cluster 1
# Internship trainee (Data Analyst): Cluster 1
#  Full Stack Engineer: Cluster 1
# Chief Data Scientist: Cluster 1
# Head of Service Science and Engineering lab: Cluster 1
# Responsible for the product: Cluster 1
# Assistant: Cluster 1
# Data Engineer Intern: Cluster 1
# Customer Service Representative: Cluster 1
# Scientist: Cluster 1
# Student Activities Coordinator: Cluster 1
# Engineer of the Technical Support Service: Cluster 1
#  Data Analyst | BI Analyst: Cluster 1
# Trandwatcher / Copywriter: Cluster 1
# Chief Executive Officier & co-founder: Cluster 1
# QA Automaton Engineer: Cluster 1
# Data Scientist trainee: Cluster 1
# Program Manager for the Data Science Track: Cluster 1
# Provectus Data Engineering: Cluster 1
# Senior System Analyst: Cluster 1
# Internship: Cluster 1
# Deputy director for science: Cluster 1
# Coach in data structures and algorithms: Cluster 1
# User Experience Lead: Cluster 1
# Community Access Program Assistant: Cluster 1
# IT Technician: Cluster 1
# Scientific Lead: Cluster 1
#  DevOps Engineer | Teaching Assistant : Cluster 1
# Computer Science Teacher: Cluster 1
# Senior Analytical Consultant: Cluster 1
# Autonomous transport systems laboratory lead engineer  : Cluster 1
# Senior Instructor: Cluster 1
# Lecturer in Computer Science: Cluster 1
# Data Science & Business Analytics: Cluster 1
# Assistant To The Dean: Cluster 1
# Assistant Project Coordinator: Cluster 1
# R&D SLAM&Calibration engineer: Cluster 1
# Instructor / TA: Cluster 1
# Mr.Android: Cluster 1
# Data Science Intern: Cluster 1
# Scientific adviser: Cluster 1
# Senior / Lead IT Recruiter: Cluster 1
# Co-Founder & COO: Cluster 1
# Master's Student: Cluster 1
# Full Stack Data Science & LLM Engineer: Cluster 1
# Blockchain Engineer: Cluster 1
# Data Scientist I: Cluster 1
# Assistant Teacher: Cluster 1
# Instructor Assistance: Cluster 1
# QA Engineer (remote job): Cluster 1
# Robotics scientist: Cluster 1
# Teaching Assistant in Charge, Introduction to Robotics: Cluster 1
# Deputy Chief Technology Officer: Cluster 1
# Quantum Engineer: Cluster 1
# Trainee: Cluster 1
# Senior Analyst: Cluster 1
# MSc Student (AI and Robotics): Cluster 1
# Senior Web Application Engineer: Cluster 1
# AI/LLM Trainer: Cluster 1
# Junior IT Recruiter: Cluster 1
# System And Database Administrator: Cluster 1
# Producer of Data Science online courses: Cluster 1
# Senior Data Scientist: Cluster 1
# Fullstack Javascript Engineer: Cluster 1
# Machine Learning Manager and Researcher in AI in Medicine: Cluster 1
# Data Engineer: Cluster 1
# Analyst Engineer: Cluster 1
# ML Engineer/Data Scientist/Web developer - Freelance: Cluster 1
# Advanced Product Advisor: Cluster 1
# Head of the laboratory of adaptive fractal antenna systems "Crohn": Cluster 1
# Front End Engineer: Cluster 1
# Lead Machine Learning Engineer: Cluster 1
# Deputy General Director: Cluster 1
# Cryptocurrency Arbitrage: Cluster 1
# Intern Java: Cluster 1
# Senior Site Reliability Engineer: Cluster 1
# Full Stack Blockchain Engineer: Cluster 1
# CIO: Cluster 1
# Food Service Worker: Cluster 1
# Quality Assurance Engineer: Cluster 1
# Backend Intern: Cluster 1
# Business Advisor: Cluster 1
# Science Director: Cluster 1
# Principal Data Scientist: Cluster 1
# C# Engineer - Intern: Cluster 1
# Android Engineer: Cluster 1
# Engineer: Cluster 1
# Senior Data Analyst/Scientist: Cluster 1
# Expert at the Supreme Court of Justice of Luxembourg: Cluster 1
# Senior Editor: Cluster 1
# AI Lead: Cluster 1
# System analyst: Cluster 1
# Associate Professor in Robotics: Cluster 1
# Data Modeler Intern: Cluster 1
# Intern Java/Kotlin: Cluster 1
# Freelancer - Data Scientist: Cluster 1
# Deputy Head of International Affairs Department: Cluster 1
# Python Data Engineer: Cluster 1
# Chief Engineer: Cluster 1
# Junior scientific worker: Cluster 1
# Intern, Business Innovations & IT: Cluster 1
# Student MSIT-SE: Cluster 1
# Senior Quality Assurance Automation Engineer: Cluster 1
# Faculty Intern: Cluster 1
# Teaching Assistant on Algorithms and Data Structures course: Cluster 1
# Independent Consultant: Cluster 1
#  Network Architect: Cluster 1
# Senior Data Scientist, Retail Segment: Cluster 1
# Aide to the Chairman of the SKOLKOVO Coordination Council: Cluster 1

# %%
plt.figure(figsize=(15, 15))
scatter = plt.scatter(embedding_2d[:, 0], embedding_2d[:, 1], s=5, c=labels, alpha=0.8)

plt.title("Position Embeddings in 2D Space", fontsize=16)
plt.xlabel("UMAP Dimension 1")
plt.ylabel("UMAP Dimension 2")
plt.grid(True)
plt.show()
